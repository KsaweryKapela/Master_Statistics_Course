# %%
import numpy as np
import matplotlib.pyplot as plt
import pingouin as pg
import pandas as pd
import os

os.environ['OUTDATED_IGNORE'] = '1'

mean1 = 4
mean2 = 3.8
mean3 = 7

N = 30

stdev = 2

data1 = mean1 + np.random.randn(N)*stdev
data2 = mean2 + np.random.randn(N)*stdev
data3 = mean3 + np.random.randn(N)*stdev

datamat = np.vstack((data1,data2,data3)).T

df = pd.DataFrame(data=datamat,columns=['d1','d2','d3'])
df
# Out:
#           d1        d2         d3
# 0   1.858915  5.484173   7.000485
# 1   4.878132  1.080015   5.667592
# 2   2.934195  8.125729  11.429620
# 3   2.881581  6.871241   7.562411
# 4   4.480837  8.717360   1.829547
# 5   5.322561 -0.210762  12.207247
# 6   6.302921  3.552827   5.460817
# 7   3.238059  4.213368  10.273214
# 8   3.665041  5.481382   8.361249
# 9   0.394181  5.574960   6.005805
# 10  2.889428  4.694454   6.593567
# 11  2.364102  0.947996   7.163586
# 12  0.313893  1.685190   2.855302
# 13  5.098672  1.993381   7.232721
# 14  2.461884  0.463840   7.066996
# 15  3.891669  1.655400   8.709510
# 16  3.574574  5.208756   5.078901
# 17  2.776020  6.131719   6.343024
# 18  4.760296  2.369200   6.985914
# 19  2.223446  5.355079   5.942869
# 20  2.150225  5.598242   7.801582
# 21  7.214691  3.694200   8.968187
# 22  4.769761  3.689201   4.056223
# 23  2.592158  3.932803   9.282428
# 24  0.981731  5.587998   6.257758
# 25  1.925529  5.006104   6.072488
# 26  1.146459  4.371059   4.680094
# 27  3.685913  6.299348   7.557315
# 28  5.302924  0.889069   5.277755
# 29  5.902401  6.749445   0.684379

# %%
pg.rm_anova(data=df,detailed=True)
# Out:
#    Source          SS  DF         MS          F     p-unc       ng2       eps
# 0  Within  176.464692   2  88.232346  16.054292  0.000003  0.292575  0.931589
# 1   Error  318.760618  58   5.495873        NaN       NaN       NaN       NaN

# %%
df.boxplot();

# %%
data = [
    [8, 7, 6, 7],
    [5, 8, 5, 6],
    [6, 5, 3, 4],
    [6, 6, 7, 3],
    [8, 10, 8, 6],
    [6, 5, 6, 3],
    [6, 5, 2, 3],
    [9, 9, 9, 6],
    [5, 4, 3, 7],
    [7, 6, 6, 5]]


df = pd.DataFrame(data=data,columns=['1','2','3','4'])

pg.rm_anova(data=df,detailed=True)
# Out:
#    Source    SS  DF        MS         F     p-unc       ng2       eps
# 0  Within  18.2   3  6.066667  3.615894  0.025787  0.130372  0.697356
# 1   Error  45.3  27  1.677778       NaN       NaN       NaN       NaN
